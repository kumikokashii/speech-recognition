# %%
# %load_ext autoreload
# %autoreload 2

#import builtins  # Not needed unless saving for github
#builtins.use_bokeh_screenshot = True  # Not needed unless saving for github

import pickle

from bokeh.io import output_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="67e64059-358b-428e-ab1d-e6c884de2c13">Loading BokehJS ...</span>
#     </div>

# %%
# Need this while editing Log class so it gets autoloaded
from graphs.helpers import *

# %%
path2log = 'logs/TestLSTM_trial_graph_trial_run_01.log'

# %%
log = pickle.load(open(path2log, 'rb'))

# %%
log.show_progress()
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="c9df8d18-bd01-41fc-a5be-56c1a72adead"></div>
# </div>
