# %%
# %load_ext autoreload
# %autoreload 2

import builtins  # Not needed unless saving for github
builtins.use_bokeh_screenshot = True  # Not needed unless saving for github

import pickle
from kaggle_speech_recog.graphs.train_log import *

from bokeh.io import output_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="17c4bb19-5934-43dd-90ed-a44ff3cdc1bc">Loading BokehJS ...</span>
#     </div>

# %%
path2log = 'logs/TestSpectrogramConv_trial_graph_trial_run_01.log'

# %%
log = pickle.load(open(path2log, 'rb'))
log.add_ave_accu_valid()
log.show_progress()
