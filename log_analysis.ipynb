# %%
# %load_ext autoreload
# %autoreload 2

import builtins  # Not needed unless saving for github
builtins.use_bokeh_screenshot = True  # Not needed unless saving for github

import pickle
from kaggle_speech_recog.graphs.train_log import *

from bokeh.io import output_notebook
output_notebook()
# Out:
# /usr/local/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)
# /usr/local/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="703ef05f-42c8-4e1f-a4f7-8c6d75bd3f1b">Loading BokehJS ...</span>
#     </div>

# %%
path2logs = ['logs/Ensemble_graph_04_9models_run_01.log',
             'logs/Ensemble_graph_03_12models_run_01.log',
             'logs/Ensemble_graph_02_run_02_more_models.log',
             'logs/Ensemble_graph_02_run_01.log',
             'logs/Ensemble_graph_01_run_01.log',
             #'logs/SpectrogramMultiLSTMRandomInputModify2_graph_02_lower_lr_lr_decay_run_01_group_unknown.log',
             #'logs/SpectrogramMultiLSTMRandomInputModify2_graph_01_lr_decay_run_01_group_unknown.log',
             #'logs/SpectrogramMultiLSTMRandomInputModify_graph_03_lr_decay_run_01_group_unknown.log'
             #'logs/SpectrogramConcatCLSTM2_graph_01_run_01_group_unknown.log',
             #'logs/SpectrogramConcatCLSTM2_graph_01_run_01.log', 
             #'logs/SpectrogramDSConvDropout_graph_01_run_01.log',
             #'logs/SpectrogramDSConv_graph_01_run_02.log',
             #'logs/SpectrogramCLSTMBidirectional_graph_04_run_01.log',  # LB at 80%, mp=(1, 1)
             #'logs/SpectrogramCLSTMBidirectional_graph_03_run_01.log',  # LB at 85%, mp=(1, 2)
             #'logs/SpectrogramCLSTMBidirectional_graph_01_run_01.log',  # LB at 80%, mp=(1, 5), forgot BN before LSTM, no random modify
             #'logs/SpectrogramCLSTM_graph_01_run_01.log',  # LB at 80%
             #'logs/SpectrogramMaxPoolLSTM_graph_01_run_01.log',
             #'logs/SpectrogramMultiLSTMRandomInputModify_graph_04_kindof_finer_layers_run_01.log',
             #'logs/SpectrogramMultiLSTMRandomInputModify_graph_03_finer_layers_run_01.log',
             ##'logs/NoveltyDetectionSpectrogramMultiLSTMRandomInputModify_graph_01_run_01.log',
             #'logs/SpectrogramMultiLSTMRandomInputModify_graph_02_run_01.log',
             #'logs/SpectrogramMultiLSTM_graph_02_dropout075_on_input_run_05_input_melpower_spec.log',
             #'logs/SpectrogramMultiLSTM_graph_02_dropout075_on_input_run_04_add_and_multiply_noise.log',
             #'logs/SpectrogramMultiLSTM_graph_02_dropout075_on_input_run_03_add_noise.log',
             #'logs/SpectrogramMultiLSTM_graph_02_dropout075_on_input_run_02_split_noise.log',
             #'logs/SpectrogramMultiLSTM_graph_02_dropout075_on_input_run_01.log',
             #'logs/Spectrogram2Conv_graph_01_run_01.log',
            ]

# %%
log = pickle.load(open(path2logs[0], 'rb'))
log.add_ave_accu_valid()
log.show_progress()
# Out:
# /usr/local/anaconda3/lib/python3.6/site-packages/bokeh/core/json_encoder.py:80: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(type(obj), np.float):
# /usr/local/anaconda3/lib/python3.6/site-packages/selenium/webdriver/phantomjs/webdriver.py:49: UserWarning: Selenium support for PhantomJS has been deprecated, please use headless versions of Chrome or Firefox instead
#   warnings.warn('Selenium support for PhantomJS has been deprecated, please use headless '

# %%
Log.compare(path2logs, max_epoch=1500)
# Out:
# /usr/local/anaconda3/lib/python3.6/site-packages/selenium/webdriver/phantomjs/webdriver.py:49: UserWarning: Selenium support for PhantomJS has been deprecated, please use headless versions of Chrome or Firefox instead
#   warnings.warn('Selenium support for PhantomJS has been deprecated, please use headless '

# %%
check = pickle.load(open('logs/Ensemble_graph_04_9models_run_01.log', 'rb'))
check.__dict__['g_cnfg'].__dict__
# Out:
# {'X_n_features': 154,
#  'Y_vector_len': 12,
#  'flat_hiddens': [256, 256],
#  'lr_decay_rate': 1.0,
#  'lr_decay_steps': 100000000,
#  'lr_initial': 0.001,
#  'name': 'graph_04_9models'}
